# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy.random import randn

# %% [markdown]
# # Visualizing statistical relationships
#
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.
#
# ### 1. Numerical Data Ploting
# - relplot()
# - scatterplot()
# - lineplot()
#
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...
#
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()
#
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()
#
# ### 5. Controlling Ploted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes
# - etc..

# %%
df1=sns.load_dataset('tips')
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip',data=df1)

# %%
sns.set_style('darkgrid')
sns.relplot(x='total_bill',y='tip',data=df1)

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,style='size')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,style='time',hue='size')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,style='time',hue='smoker',size='size')

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df2 = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
df2.head()
# Out:
#    time     value
# 0     0 -0.985176
# 1     1 -0.758941
# 2     2 -1.365702
# 3     3 -1.062294
# 4     4 -1.928199

# %%
sns.relplot(x='time',y='value',kind='line',data=df2)

# %%
sns.relplot(x='time',y='value',kind='line',data=df2,sort=True)

# %%
df3=pd.DataFrame(randn(500,2).cumsum(axis=0),columns=['time','value'])
df3.head()
# Out:
#        time     value
# 0  2.583277 -2.047719
# 1  1.292443 -0.822518
# 2  1.569213 -0.642355
# 3  1.961727 -1.148748
# 4  1.310994 -0.610930

# %%
sns.relplot(x='time',y='value',kind='line',data=df3,sort=True)

# %%
df4 = sns.load_dataset('fmri')
df4.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal',data=df4)

# %%
sns.relplot(x='timepoint',y='signal',data=df4,kind='line')

# %%
sns.relplot(x='timepoint',y='signal',data=df4,kind='line',ci='sd')

# %%
sns.relplot(x='timepoint',y='signal',estimator=None,data=df4,kind='line')

# %%
sns.relplot(x='timepoint',y='signal',data=df4,kind='line',hue='event')

# %%
sns.relplot(x='timepoint',y='signal',data=df4,kind='line',hue='region',style='event')

# %%
sns.relplot(x='timepoint',y='signal',data=df4,kind='line',hue='region',style='event',estimator=None)

# %%
sns.relplot(x='timepoint',y='signal',data=df4,kind='line',markers=True,style='event',estimator=None)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = df4, markers = True, dashes = False)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = df1)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = df1)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size',col_wrap=3, data = df1)

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = df1)

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = df1, hue = 'smoker', size = 'size', style = 'time')

# %%
df5=sns.load_dataset('iris')
df5.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = df5)

# %% [markdown]
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...

# %%
df6= sns.load_dataset('titanic')
df6.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# catplot
sns.catplot(x = 'day', y = 'total_bill', data = df1)

# %%
sns.catplot(y = 'day', x = 'total_bill', data = df1)

# %%
sns.catplot(x = 'day', y = 'total_bill', data = df1, jitter = False)

# %%
sns.catplot(x = 'day', y = 'tip', data = df1, kind = 'swarm', hue = 'size')

# %%
sns.catplot(x = 'smoker', y = 'tip', data = df1, order= ['No', 'Yes'])

# %%
# boxplot
sns.catplot(x = 'day', y = 'tip',kind='box', data = df1,hue='sex')

# %%
#overrlap
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = df1, hue = 'sex', dodge = False)
